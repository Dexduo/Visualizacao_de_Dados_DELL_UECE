# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2
# [notice] To update, run: C:\Users\ADM\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %% [markdown]
# ### Series Pandas Python

# %%
pandas_series = pd.Series([1, 2, 3, 4, 5])
pandas_series
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pandas_series[1]
# Out:
# np.int64(2)

# %%
pandas_series.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
pandas_series[3]
# Out:
# np.int64(4)

# %%
acidentes = pd.Series([15, 16, 34, 10, 14, 30, 22, 11, 14, 20, 23, 34], index=['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set', 'out', 'nov', 'dez'])
acidentes
# Out:
# jan    15
# fev    16
# mar    34
# abr    10
# mai    14
# jun    30
# jul    22
# ago    11
# set    14
# out    20
# nov    23
# dez    34
# dtype: int64

# %%
acidentes['abr']
# Out:
# np.int64(10)

# %%
acidentes[0:6]
# Out:
# jan    15
# fev    16
# mar    34
# abr    10
# mai    14
# jun    30
# dtype: int64

# %%
acidentes[0:6].values
# Out:
# array([15, 16, 34, 10, 14, 30])

# %%
sem1 = acidentes[0:6].values
list(map(lambda x: x * 2, sem1))
# Out:
# [np.int64(30),
#  np.int64(32),
#  np.int64(68),
#  np.int64(20),
#  np.int64(28),
#  np.int64(60)]

# %%
sem1
# Out:
# array([15, 16, 34, 10, 14, 30])

# %%
print(acidentes.mean())
print(acidentes.std())
print(acidentes.max())
print(acidentes.min())
# Out:
# 20.25
# 8.518696016303306
# 34
# 10

# %%
acidentes.describe() #observar a questão dos quartis
# Out:
# count    12.000000
# mean     20.250000
# std       8.518696
# min      10.000000
# 25%      14.000000
# 50%      18.000000
# 75%      24.750000
# max      34.000000
# dtype: float64

# %%
acidentes.sum()
# Out:
# np.int64(243)

# %%
list(filter(lambda x: x > 30, sem1))
list(map(lambda x: x > 30, sem1))
# Out:
# [np.False_, np.False_, np.True_, np.False_, np.False_, np.False_]

# %%
acidentes[6:].mean()
# Out:
# np.float64(20.666666666666668)

# %% [markdown]
# ### Dataframes Pandas Python

# %%
dataframeDefinition = {
                        'Aluno': ['Carlos', 'Eduardo', 'Ingrid', 'Juan'],
                        'Créditos Cursados': [32, 96, 64, 96],
                        'Rendimento Acadêmico': [8.50, 9.22, 7.87, 8.95],
                        'Mês de nascimento': ['Novembro', 'Julho', 'Setembro', 'Janeiro'],
                        'Curso': ['Matemática', 'Computação', 'Estatística', 'Ciência de Dados']
}

df = pd.DataFrame(dataframeDefinition)
df
# Out:
#      Aluno  Créditos Cursados  Rendimento Acadêmico Mês de nascimento  \
# 0   Carlos                 32                  8.50          Novembro
# 1  Eduardo                 96                  9.22             Julho
# 2   Ingrid                 64                  7.87          Setembro
# 3     Juan                 96                  8.95           Janeiro
#
#               Curso
# 0        Matemática
# 1        Computação
# 2       Estatística
# 3  Ciência de Dados

# %%
df.iloc[3]
# Out:
# Aluno                               Juan
# Créditos Cursados                     96
# Rendimento Acadêmico                8.95
# Mês de nascimento                Janeiro
# Curso                   Ciência de Dados
# Name: 3, dtype: object

# %%
df['Rendimento Acadêmico']
# Out:
# 0    8.50
# 1    9.22
# 2    7.87
# 3    8.95
# Name: Rendimento Acadêmico, dtype: float64

# %%
df['Rendimento Acadêmico'].values.mean()
# Out:
# np.float64(8.635)

# %%
df['Rendimento Acadêmico'].mean()
# Out:
# np.float64(8.635)

# %%
df['Rendimento Acadêmico'].describe()
# Out:
# count    4.000000
# mean     8.635000
# std      0.590169
# min      7.870000
# 25%      8.342500
# 50%      8.725000
# 75%      9.017500
# max      9.220000
# Name: Rendimento Acadêmico, dtype: float64

# %%
df.describe()
# Out:
#        Créditos Cursados  Rendimento Acadêmico
# count           4.000000              4.000000
# mean           72.000000              8.635000
# std            30.637667              0.590169
# min            32.000000              7.870000
# 25%            56.000000              8.342500
# 50%            80.000000              8.725000
# 75%            96.000000              9.017500
# max            96.000000              9.220000

# %% [markdown]
# ## Trabalhando com CSV

# %%
df = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/alcohol-consumption/drinks.csv')

# %%
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 1                             4.9
# 2                             0.7
# 3                            12.4
# ...

# %%
df.head(6)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
#
#    total_litres_of_pure_alcohol
# 0                           0.0
# 1                           4.9
# 2                           0.7
# 3                          12.4
# 4                           5.9
# 5                           4.9

# %%
df[df['country'] == 'Brazil']
# Out:
#    country  beer_servings  spirit_servings  wine_servings  \
# 23  Brazil            245              145             16
#
#     total_litres_of_pure_alcohol
# 23                           7.2

# %%
df[df['total_litres_of_pure_alcohol'] >= 12]
# Out:
#       country  beer_servings  spirit_servings  wine_servings  \
# 3     Andorra            245              138            312
# 15    Belarus            142              373             42
# 98  Lithuania            343              244             56
#
#     total_litres_of_pure_alcohol
# 3                           12.4
# 15                          14.4
# 98                          12.9

# %%
df[df['total_litres_of_pure_alcohol'] == 0].head()
# Out:
#         country  beer_servings  spirit_servings  wine_servings  \
# 0   Afghanistan              0                0              0
# 13   Bangladesh              0                0              0
# 46  North Korea              0                0              0
# 79         Iran              0                0              0
# 90       Kuwait              0                0              0
#
#     total_litres_of_pure_alcohol
# 0                            0.0
# 13                           0.0
# 46                           0.0
# 79                           0.0
# 90                           0.0

# %%
df.sort_values(by='wine_servings', ascending=False).head()
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 61        France            127              151            370
# 136     Portugal            194               67            339
# 3        Andorra            245              138            312
# 166  Switzerland            185              100            280
# 48       Denmark            224               81            278
#
#      total_litres_of_pure_alcohol
# 61                           11.8
# 136                          11.0
# 3                            12.4
# 166                          10.2
# 48                           10.4
